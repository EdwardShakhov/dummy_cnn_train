# %%
import librosa
from librosa.feature import melspectrogram
from librosa.core import load
from librosa.display import specshow
from librosa import power_to_db

import matplotlib.pyplot as plt

# from utils.preprocessing import extract_log_mel_feats
# run git log чтобы посмотреть предыдущие версии кода, где не было исправлений

# %%
import os
from tqdm import tqdm
import pickle
import pandas as pd
import numpy as np

from librosa.feature import melspectrogram
from librosa.core import load as load_wav
from librosa import power_to_db


def extract_log_mel_feats(set_type, path_to_csv, path_to_files, out_path, sr, fft_size, hop, n_mels):
    """
    Extract features from given files and store them in binary format.

    :param set_type:
    :param path_to_csv: path to loaded csv
    :param path_to_files: path to loaded data
    :param out_path: path to store extracted features
    :param sr: input files sample rate
    :param fft_size: size of fft window
    :param hop: hop size
    :param n_mels: number of mel band

    :return:

    """
    set_type = set_type.lower()
    if set_type not in ['train', 'test']:
        raise Exception('Such set type not supported: {}'.format(set_type))

    feats = []

    if set_type == 'train':
        meta = pd.read_csv(path_to_csv, skiprows=1, names=['fname', 'label', 'manually_verified'])

        file_names = list(meta['fname'])
        n_files = len(file_names)
        labels = list(meta['label'])

        uniq_labels = np.sort(np.unique(labels))
        label_to_id = {label: i for i, label in enumerate(uniq_labels)}

        print('Total files:', n_files)

        for i, (file_name, label) in tqdm(enumerate(zip(file_names, labels))):
            wav_data, sr = load_wav(os.path.join(path_to_files, file_name), sr=sr)
            mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
            log_mel_spec = power_to_db(mel_spec, ref=np.max)
            feats.append({
                'fname': file_name,
                'feature': log_mel_spec,
                'label_id': label_to_id[label]
            })
        pickle.dump(feats, open(out_path, 'wb'))    
        return label_to_id
    else:
        for i, file_name in tqdm(enumerate(os.listdir(path_to_files))):
            wav_data, sr = load_wav(os.path.join(path_to_files, file_name), sr=sr)
            if len(wav_data) == 0:
                # print('Empty file:', file_name)
                wav_data = np.zeros(sr)
            mel_spec = melspectrogram(wav_data, n_fft=fft_size, n_mels=n_mels, fmax=sr // 2)
            log_mel_spec = power_to_db(mel_spec, ref=np.max)
            feats.append({
                'fname': file_name,
                'feature': log_mel_spec,
            })

    pickle.dump(feats, open(out_path, 'wb'))

# %%
train_folder = 'C:/Users/e_shakhov/Desktop/dataset/train/'
test_folder = 'C:/Users/e_shakhov/Desktop/dataset/train/'

sample_rate = 22050
fft_size = 1024
overlap = 4
hop = fft_size // overlap
mels = 64

# %%
wav_data, sr = load(os.path.join(test_folder, '85d37b6877368c540dfe.wav'), sr=sample_rate)
mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=mels, 
                          fmax=sample_rate//2)

plt.figure(figsize=(10, 4))
colors = 'viridis'
specshow(mel_spec, y_axis='mel', fmax=sample_rate//2, x_axis='time', cmap=colors)
plt.colorbar(format='%+2.0f дБ')
plt.title('Мелспектрограмма')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 4))
specshow(power_to_db(mel_spec, ref=np.max), y_axis='mel',
         fmax=sample_rate//2, x_axis='time', cmap=colors)
plt.colorbar(format='%+2.0f дБ')
plt.title('Логарифм мелспектрограммы')
plt.tight_layout()
plt.show()

# %%
path_to_csv = os.path.join('C:/Users/e_shakhov/Desktop/dataset/train/', 'train.csv')

pickle_train_path = os.path.join('train.pickle')
# pickle_test_path = os.path.join('./data', 'test.pickle')

label_to_id = extract_log_mel_feats('train', path_to_csv, train_folder, pickle_train_path, sample_rate, fft_size, hop, mels)
id_to_label = [label for label, i in label_to_id.items()]

# extract_log_mel_feats('test', '', test_folder, pickle_test_path, sample_rate, fft_size, hop, mels)
# Out:
# 0it [00:00, ?it/s]
# Total files: 5683
# 5683it [09:29,  9.98it/s]

# %%
import numpy as np
import pandas as pd
import soundfile as sf
import torch.nn.functional as F
import torch.nn as nn
import torch


class DummyNetwork(nn.Module):
    def __init__(self):
        super(DummyNetwork, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=5, stride=(2, 2))
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=96, kernel_size=3, stride=(1, 1))
        self.conv3 = nn.Conv2d(in_channels=96, out_channels=64, kernel_size=3, stride=(1, 1))
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=(1, 1))
        
        self.mp = nn.MaxPool2d(kernel_size=(2, 2), stride=(1, 1))
        
        self.dropout1 = nn.Dropout(p=0.3)
        self.dropout2 = nn.Dropout(p=0.3)
        self.dropout3 = nn.Dropout(p=0.3)
        self.dropout4 = nn.Dropout(p=0.3)
        
        self.bn1 = nn.BatchNorm2d(num_features=64)
        self.bn2 = nn.BatchNorm2d(num_features=96)
        self.bn3 = nn.BatchNorm2d(num_features=64)
        self.bn4 = nn.BatchNorm2d(num_features=64)
        
        self.flat = nn.Flatten()
        
        # 33856 - должно соответствовать форме self.flat
        self.fc1 = nn.Linear(25600, 41)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.mp(x)
        x = self.dropout1(x)
        
        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.mp(x)
        x = self.dropout2(x)
        
        x = self.conv3(x)
        x = self.bn3(x)
        x = F.relu(x)
        x = self.mp(x)
        x = self.dropout3(x)
        
        x = self.conv4(x)
        x = self.bn4(x)
        x = F.relu(x)
        x = self.mp(x)
        x = self.dropout4(x)
        
        x = self.flat(x)
        # здесь можно еще добавить полносвязных слой или слои
        x = self.fc1(x)
        return x

# %%
random_input = torch.randn(1, 1, 64, 64, requires_grad=True)
network = DummyNetwork()
output = network(random_input)
print(output)
# Out:
# tensor([[ 1.1961, -0.9295, -1.1971,  1.5125,  0.4197,  0.8289, -0.3674, -0.5021,
#          -0.5634,  2.0184,  0.3473,  0.8527, -1.1449, -0.0512, -0.2895,  0.4183,
#           1.1974, -0.5606, -0.7061, -0.6233, -0.5473, -1.6099,  0.3641, -0.5520,
#          -0.4781, -0.9124, -0.5804,  1.5974,  0.0443,  0.1482, -0.2800,  0.0793,
#          -0.3950, -0.5547,  0.6778, -1.4980,  0.1517, -0.5229, -1.2490,  0.2272,
#           0.1218]], grad_fn=<AddmmBackward>)

# %%
import torch.optim as optim


criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(network.parameters(), lr=0.001)
optimizer.zero_grad()

random_input = torch.randn(3, 1, 64, 64, requires_grad=True)

output = network(random_input)
target = torch.empty(3, dtype=torch.long).random_(5)

loss = criterion(output, target)

print(loss.item())

loss.backward()
optimizer.step()
# Out:
# 3.498347043991089

# %%
import pickle

pickle_train_data = pickle.load(open(pickle_train_path, 'rb'))

# %%
def prepare_shape(feature):
    tmp = feature
    N = 64 # размер во времени (можно увеличить, должно стать лучше)
    while tmp.shape[1] < N:
        # можно попробовать сделать np.pad для коротких файлов, вместо повторения до необходимой длины
        tmp = np.hstack((tmp, tmp))
    # случайный сдвиг должен улучшить результат (для этого нужно функцию перенести в EventDetectionDataset)
    tmp = tmp[np.newaxis, :, :N]
    return tmp

# %%
# можно улучшить, используя сбалансированное валидационное множество
# гуглить stratified train test split sklearn
validation_set_size = 800

x_val = []
y_val = []

x_tr = []
y_tr = []

for i, row in enumerate(pickle_train_data):
    feature = prepare_shape(row['feature'])
    if i < validation_set_size:
        x_val.append(feature)
        y_val.append(row['label_id'])
    else:
        x_tr.append(feature)
        y_tr.append(row['label_id'])
x_val = np.asarray(x_val)
x_tr = np.asarray(x_tr)

y_val = np.asarray(y_val)
y_tr = np.asarray(y_tr)

# %%
from torch.utils.data import Dataset


class EventDetectionDataset(Dataset):
    def __init__(self, x, y=None):
        self.x = x
        self.y = y
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        # добавить сюда prepare_shape()
        if self.y is not None:
            return self.x[idx], self.y[idx]
        return self.x[idx]

# %%
train_dset = EventDetectionDataset(x_tr, y_tr)
val_dset = EventDetectionDataset(x_val, y_val)

# %%
sample_x, sample_y = val_dset[2]
print(sample_y)
# print(id_to_label[sample_y])
plt.figure(figsize=(10, 4))
colors = 'viridis'
specshow(sample_x[0], y_axis='mel', fmax=sample_rate//2, x_axis='time', cmap=colors)
plt.colorbar(format='%+2.0f дБ')
plt.title('Мелспектрограмма')
plt.tight_layout()
plt.show()
# Out:
# 14

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_dset, batch_size=41, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dset, batch_size=41, shuffle=False, num_workers=0)

# %%
from sklearn.metrics import accuracy_score

# %%
n_epoch = 75
criterion = nn.CrossEntropyLoss()
network = DummyNetwork()
# можно попробовать другой optimizer, тоже считается улучшением
optimizer = optim.Adam(network.parameters(), lr=0.0015)

train_loss = []
val_loss = []

train_acc = []
val_acc = []

for e in range(n_epoch):
    print('epoch #', e)
    # train
    loss_list = []
    outputs = []
    targets = []
    for i_batch, sample_batched in enumerate(train_loader):
        x, y = sample_batched
        optimizer.zero_grad()

        output = network(x)
        outputs.append(output.detach().numpy().argmax(axis=1))
    
        target = y
        targets.append(target)
        
        loss = criterion(output, target.long())
        loss_list.append(loss.item())
        loss.backward()
        optimizer.step()
    y_true = np.hstack(targets)
    y_pred = np.hstack(outputs)
    acc = accuracy_score(y_true, y_pred)
    train_loss.append(np.mean(loss_list))
    train_acc.append(acc)
    print('mean train loss:', train_loss[-1])
    print('train accuracy:', acc)
    
    
    loss_list = []
    outputs = []
    targets = []
    with torch.no_grad():
        for i_batch, sample_batched in enumerate(val_loader):
            x, y = sample_batched
#             optimizer.zero_grad()

            output = network(x)
            outputs.append(output.detach().numpy().argmax(axis=1))

            target = y
            targets.append(target)

            loss = criterion(output, target.long())
            loss_list.append(loss.item())
#             loss.backward()
#             optimizer.step()
            
        y_true = np.hstack(targets)
        y_pred = np.hstack(outputs)
        acc = accuracy_score(y_true, y_pred)
        val_loss.append(np.mean(loss_list))
        val_acc.append(acc)
        print('mean val loss:', val_loss[-1])
        print('val accuracy:', acc)
# Out:
# epoch # 0
# mean train loss: 9.602501614888508
# train accuracy: 0.07577309031333197
# mean val loss: 5.070456719398498
# val accuracy: 0.1225
# epoch # 1
# mean train loss: 4.707295499245325
# train accuracy: 0.13721073110792545
# mean val loss: 3.759392499923706
# val accuracy: 0.1575
# epoch # 2
# mean train loss: 3.780633693933487
# train accuracy: 0.19455252918287938
# mean val loss: 3.2708754777908324
# val accuracy: 0.21
# epoch # 3
# mean train loss: 3.1335107465585073
# train accuracy: 0.245136186770428
# mean val loss: 2.7934863924980164
# val accuracy: 0.24125
# epoch # 4
# mean train loss: 2.6671117544174194
# train accuracy: 0.3067786197010035
# mean val loss: 2.588793182373047
# val accuracy: 0.305
# epoch # 5
# mean train loss: 2.4384214262167614
# train accuracy: 0.35900061437640796
# mean val loss: 2.4951616525650024
# val accuracy: 0.35625
# epoch # 6
# mean train loss: 2.3109091967344284
# train accuracy: 0.396067990989146
# mean val loss: 2.319662815332413
# val accuracy: 0.37125
# epoch # 7
# mean train loss: 2.107111097375552
# train accuracy: 0.4269916035224247
# mean val loss: 2.267055571079254
# val accuracy: 0.3875
# epoch # 8
# mean train loss: 1.9768292089303334
# train accuracy: 0.4683596149907844
# mean val loss: 2.1805930733680725
# val accuracy: 0.425
# epoch # 9
# mean train loss: 1.849843896428744
# train accuracy: 0.48801966004505426
# mean val loss: 2.1508824229240417
# val accuracy: 0.42875
# epoch # 10
# mean train loss: 1.739439344406128
# train accuracy: 0.5232439074339545
# mean val loss: 2.2232747852802275
# val accuracy: 0.42375
# epoch # 11
# mean train loss: 1.746099383632342
# train accuracy: 0.527544542289576
# mean val loss: 2.0728915989398957
# val accuracy: 0.44875
# epoch # 12
# mean train loss: 1.5202233870824178
# train accuracy: 0.5820192504607823
# mean val loss: 2.0889908969402313
# val accuracy: 0.44125
# epoch # 13
# mean train loss: 1.4832229082783064
# train accuracy: 0.5773090313331968
# mean val loss: 2.1438051223754884
# val accuracy: 0.44875
# epoch # 14
# mean train loss: 1.3568631082773208
# train accuracy: 0.6201105877534303
# mean val loss: 2.134016865491867
# val accuracy: 0.4525
# epoch # 15
# mean train loss: 1.255820095539093
# train accuracy: 0.6442760597993037
# mean val loss: 2.13462917804718
# val accuracy: 0.46125
# epoch # 16
# mean train loss: 1.1497301027178763
# train accuracy: 0.6715134138849068
# mean val loss: 2.242828643321991
# val accuracy: 0.45875
# epoch # 17
# mean train loss: 1.1877358521024386
# train accuracy: 0.6627073520376817
# mean val loss: 2.2299883127212525
# val accuracy: 0.45125
# epoch # 18
# mean train loss: 1.1467706883947055
# train accuracy: 0.6635265205816097
# mean val loss: 2.2704737961292265
# val accuracy: 0.4275
# epoch # 19
# mean train loss: 0.9674888988335927
# train accuracy: 0.7190251894327258
# mean val loss: 2.457002103328705
# val accuracy: 0.4475
# epoch # 20
# mean train loss: 1.0426171511411666
# train accuracy: 0.6991603522424739
# mean val loss: 2.235139471292496
# val accuracy: 0.45625
# epoch # 21
# mean train loss: 0.9475986525416374
# train accuracy: 0.7321318861355723
# mean val loss: 2.28628888130188
# val accuracy: 0.45125
# epoch # 22
# mean train loss: 0.8592559218406677
# train accuracy: 0.7454433749744009
# mean val loss: 2.397358649969101
# val accuracy: 0.44875
# epoch # 23
# mean train loss: 0.840934877221783
# train accuracy: 0.7556829817734999
# mean val loss: 2.3343322932720185
# val accuracy: 0.475
# epoch # 24
# mean train loss: 0.6961606465280056
# train accuracy: 0.79193118984231
# mean val loss: 2.547662854194641
# val accuracy: 0.44125
# epoch # 25
# mean train loss: 0.7354888247946898
# train accuracy: 0.7937743190661478
# mean val loss: 2.6701902389526366
# val accuracy: 0.43625
# epoch # 26
# mean train loss: 0.8356441455582778
# train accuracy: 0.7575261109973377
# mean val loss: 2.4441885709762574
# val accuracy: 0.4625
# epoch # 27
# mean train loss: 0.6044348287085692
# train accuracy: 0.8287937743190662
# mean val loss: 2.6175030529499055
# val accuracy: 0.48
# epoch # 28
# mean train loss: 0.653919084991018
# train accuracy: 0.8234691787835348
# mean val loss: 2.5286746263504027
# val accuracy: 0.45
# epoch # 29
# mean train loss: 0.6608107807269941
# train accuracy: 0.7988941224656974
# mean val loss: 2.6073968172073365
# val accuracy: 0.48375
# epoch # 30
# mean train loss: 0.4685910454640786
# train accuracy: 0.8607413475322547
# mean val loss: 2.9014674961566924
# val accuracy: 0.44875
# epoch # 31
# mean train loss: 0.5146363028635581
# train accuracy: 0.8439483923817326
# mean val loss: 2.9074483036994936
# val accuracy: 0.435
# epoch # 32
# mean train loss: 0.41637419288357097
# train accuracy: 0.8705713700593897
# mean val loss: 2.91912242770195
# val accuracy: 0.45375
# epoch # 33
# mean train loss: 0.45883654163529475
# train accuracy: 0.8654515666598402
# mean val loss: 3.182658725976944
# val accuracy: 0.4425
# epoch # 34
# mean train loss: 0.4487640089044968
# train accuracy: 0.86852344869957
# mean val loss: 3.024725395441055
# val accuracy: 0.47
# epoch # 35
# mean train loss: 0.4583210134257873
# train accuracy: 0.868318656563588
# mean val loss: 3.1999888002872465
# val accuracy: 0.45125
# epoch # 36
# mean train loss: 0.3758519098162651
# train accuracy: 0.8908457915216056
# mean val loss: 3.0712620615959167
# val accuracy: 0.45
# epoch # 37
# mean train loss: 0.37784794929126897
# train accuracy: 0.8933032971533893
# mean val loss: 3.4234482884407043
# val accuracy: 0.45
# epoch # 38
# mean train loss: 0.331995950328807
# train accuracy: 0.8988326848249028
# mean val loss: 3.435351175069809
# val accuracy: 0.44875
# epoch # 39
# mean train loss: 0.354578351136297
# train accuracy: 0.8965799713291009
# mean val loss: 2.949957603216171
# val accuracy: 0.46
# epoch # 40
# mean train loss: 0.2913080483675003
# train accuracy: 0.9199262748310465
# mean val loss: 3.742572820186615
# val accuracy: 0.44875
# epoch # 41
# mean train loss: 0.3542834454526504
# train accuracy: 0.906205201720254
# mean val loss: 3.5201351046562195
# val accuracy: 0.4375
# epoch # 42
# mean train loss: 0.41098779054979484
# train accuracy: 0.8758959655949211
# mean val loss: 3.272127103805542
# val accuracy: 0.45125
# epoch # 43
# mean train loss: 0.26747741891692084
# train accuracy: 0.9197214826950645
# mean val loss: 3.4970769047737122
# val accuracy: 0.4375
# epoch # 44
# mean train loss: 0.22914008069540917
# train accuracy: 0.9301658816301454
# mean val loss: 3.89882550239563
# val accuracy: 0.4575
# epoch # 45
# mean train loss: 0.22761043108378848
# train accuracy: 0.933852140077821
# mean val loss: 3.833356672525406
# val accuracy: 0.4425
# epoch # 46
# mean train loss: 0.23309841269704823
# train accuracy: 0.9295515052221994
# mean val loss: 3.7581680536270143
# val accuracy: 0.46
# epoch # 47
# mean train loss: 0.18189346733658265
# train accuracy: 0.9467540446446856
# mean val loss: 3.6066924810409544
# val accuracy: 0.465
# epoch # 48
# mean train loss: 0.22530991428842148
# train accuracy: 0.9313946344460373
# mean val loss: 3.684414505958557
# val accuracy: 0.4475
# epoch # 49
# mean train loss: 0.18073377018639197
# train accuracy: 0.9463444603727217
# mean val loss: 3.9713231444358827
# val accuracy: 0.43625
# epoch # 50
# mean train loss: 0.20049651742447167
# train accuracy: 0.9410198648371902
# mean val loss: 4.169830238819122
# val accuracy: 0.4625
# epoch # 51
# mean train loss: 0.16171108066725234
# train accuracy: 0.953102600860127
# mean val loss: 4.1622882843017575
# val accuracy: 0.45
# epoch # 52
# mean train loss: 0.23589881854131817
# train accuracy: 0.933647347941839
# mean val loss: 4.011368161439895
# val accuracy: 0.44625
# epoch # 53
# mean train loss: 0.22514151910630364
# train accuracy: 0.9350808928937129
# mean val loss: 4.0146823048591616
# val accuracy: 0.46
# epoch # 54
# mean train loss: 0.16944912481121718
# train accuracy: 0.9506450952283433
# mean val loss: 4.023415374755859
# val accuracy: 0.44625
# epoch # 55
# mean train loss: 0.2222842602059245
# train accuracy: 0.934671308621749
# mean val loss: 3.937580716609955
# val accuracy: 0.455
# epoch # 56
# mean train loss: 0.23296134555712342
# train accuracy: 0.9330329715338931
# mean val loss: 3.953051745891571
# val accuracy: 0.47125
# epoch # 57
# mean train loss: 0.175822821771726
# train accuracy: 0.9514642637722711
# mean val loss: 3.9375025749206545
# val accuracy: 0.45875
# epoch # 58
# mean train loss: 0.14172224222371976
# train accuracy: 0.9602703256194962
# mean val loss: 4.10746842622757
# val accuracy: 0.47375
# epoch # 59
# mean train loss: 0.14752727216109635
# train accuracy: 0.962523039115298
# mean val loss: 4.654057455062866
# val accuracy: 0.45375
# epoch # 60
# mean train loss: 0.2042470618422764
# train accuracy: 0.9420438255171002
# mean val loss: 4.397744870185852
# val accuracy: 0.45375
# epoch # 61
# mean train loss: 0.1656852850380043
# train accuracy: 0.9596559492115503
# mean val loss: 4.21234747171402
# val accuracy: 0.43875
# epoch # 62
# mean train loss: 0.35021096738055346
# train accuracy: 0.9043620724964161
# mean val loss: 3.9612115025520325
# val accuracy: 0.455
# epoch # 63
# mean train loss: 0.246241442921261
# train accuracy: 0.9262748310464878
# mean val loss: 3.90267128944397
# val accuracy: 0.46375
# epoch # 64
# mean train loss: 0.14415028785976272
# train accuracy: 0.9582224042596764
# mean val loss: 4.625492691993713
# val accuracy: 0.46
# epoch # 65
# mean train loss: 0.15246051906142383
# train accuracy: 0.9559696907638746
# mean val loss: 4.439251673221588
# val accuracy: 0.4575
# epoch # 66
# mean train loss: 0.11403120272249605
# train accuracy: 0.9655949211550277
# mean val loss: 4.495059990882874
# val accuracy: 0.4625
# epoch # 67
# mean train loss: 0.10606002163258381
# train accuracy: 0.9686668031947573
# mean val loss: 4.588753664493561
# val accuracy: 0.45125
# epoch # 68
# mean train loss: 0.08911830313348522
# train accuracy: 0.9746057751382347
# mean val loss: 4.77948739528656
# val accuracy: 0.45
# epoch # 69
# mean train loss: 0.10550040921176938
# train accuracy: 0.9692811796027032
# mean val loss: 5.225728166103363
# val accuracy: 0.45375
# epoch # 70
# mean train loss: 0.12367057916805303
# train accuracy: 0.9643661683391358
# mean val loss: 4.483520770072937
# val accuracy: 0.45375
# epoch # 71
# mean train loss: 0.08256977517982401
# train accuracy: 0.9762441122260905
# mean val loss: 4.817987847328186
# val accuracy: 0.46875
# epoch # 72
# mean train loss: 0.10398635913152247
# train accuracy: 0.9709195166905591
# mean val loss: 4.750713431835175
# val accuracy: 0.45875
# epoch # 73
# mean train loss: 0.09003194556183493
# train accuracy: 0.9741961908662707
# mean val loss: 4.580305814743042
# val accuracy: 0.45625
# epoch # 74
# mean train loss: 0.08685943722569694
# train accuracy: 0.9754249436821626
# mean val loss: 4.652079713344574
# val accuracy: 0.4575

# %%
epochs = np.arange(1, n_epoch+1)

axes = plt.gca()
axes.set_ylim([0,max(max(train_loss), max(val_loss))+1])
plt.plot(epochs, train_loss, 'r', label='train')
plt.plot(epochs, val_loss, 'b', label='val')
plt.title('loss')
plt.xlabel('epoch number')
plt.ylabel('loss value')
plt.legend()
plt.grid()
plt.show()


axes = plt.gca()
axes.set_ylim([0,1])
plt.plot(epochs, train_acc, 'r', label='train')
plt.plot(epochs, val_acc, 'b', label='val')
plt.title('accuracy')
plt.xlabel('epoch number')
plt.ylabel('accuracy value')
plt.legend()
plt.grid()
plt.show()
